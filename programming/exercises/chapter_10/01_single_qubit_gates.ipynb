# %% [markdown]
# # Portas de Um Qubit
#
# ## Objetivo
# Praticar todas as portas básicas de um qubit e visualizar seus efeitos na Bloch Sphere.
#
# ## Portas Abordadas
# - **X (NOT):** Rotação de π em torno do eixo X
# - **Y:** Rotação de π em torno do eixo Y
# - **Z:** Rotação de π em torno do eixo Z
# - **H (Hadamard):** Cria superposição
# - **S, T:** Portas de fase
#
# ## Referências
# - Livro: Capítulo 10
# - [Qiskit Textbook](https://qiskit.org/textbook/ch-states/single-qubit-gates.html)

# %%
# Imports
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector, plot_histogram
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Função Auxiliar para Visualização

# %%
def visualize_gate(gate_name: str, circuit: QuantumCircuit):
    """Visualiza o circuito e o estado na Bloch Sphere."""
    print(f"=== Porta {gate_name} ===")
    display(circuit.draw('mpl'))
    
    state = Statevector.from_instruction(circuit)
    display(plot_bloch_multivector(state))
    
    print(f"Statevector: {state}")
    print()

# %% [markdown]
# ## 1. Estado Inicial |0⟩

# %%
# TODO: Criar circuito vazio (só |0⟩) e visualizar

# %% [markdown]
# ## 2. Porta X (NOT)

# %%
# TODO: Aplicar X e visualizar
# O que acontece com |0⟩?

# %% [markdown]
# ## 3. Porta H (Hadamard)

# %%
# TODO: Aplicar H e visualizar
# Para onde vai o vetor na Bloch Sphere?

# %% [markdown]
# ## 4. Porta Z

# %%
# TODO: Aplicar H -> Z e visualizar
# Por que aplicamos H antes de Z?

# %% [markdown]
# ## 5. Porta Y

# %%
# TODO: Aplicar Y em |0⟩ e visualizar

# %% [markdown]
# ## 6. Portas S e T (Fase)

# %%
# TODO: Aplicar H -> S e visualizar
# TODO: Aplicar H -> T e visualizar
# Qual a diferença entre S e T?

# %% [markdown]
# ## 7. Composição de Portas
#
# Verifique as seguintes identidades:

# %%
# TODO: Verificar que X·X = I (identidade)
# TODO: Verificar que H·H = I
# TODO: Verificar que H·X·H = Z

# %% [markdown]
# ## 8. Exercício: Criar Estado Específico
#
# Use portas para criar o estado |−⟩ = (|0⟩ - |1⟩) / √2

# %%
# TODO: Criar |−⟩ a partir de |0⟩
# Dica: Quais portas você precisa?

# %% [markdown]
# ## 9. Conclusão
#
# Responda:
# - Qual porta cria superposição?
# - O que a porta Z faz na prática?
# - Por que as portas são chamadas de "rotações"?

# %% [markdown]
# **Resposta:**
#
# _TODO: Escrever sua análise aqui_
