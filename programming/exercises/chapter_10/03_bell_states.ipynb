# %% [markdown]
# # Estados de Bell (Emaranhamento)
#
# ## Objetivo
# Criar e medir os 4 estados de Bell - os estados maximamente emaranhados.
#
# ## Os 4 Estados de Bell
# - |Φ+⟩ = (|00⟩ + |11⟩) / √2
# - |Φ-⟩ = (|00⟩ - |11⟩) / √2
# - |Ψ+⟩ = (|01⟩ + |10⟩) / √2
# - |Ψ-⟩ = (|01⟩ - |10⟩) / √2
#
# ## Referências
# - Livro: Capítulo 10
# - [Qiskit Textbook](https://qiskit.org/textbook/ch-gates/multiple-qubits-entangled-states.html)

# %%
# Imports
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram, plot_bloch_multivector
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Estado |Φ+⟩ (Bell State Padrão)
#
# |Φ+⟩ = (|00⟩ + |11⟩) / √2

# %%
def create_bell_phi_plus() -> QuantumCircuit:
    """
    Cria o estado |Φ+⟩.
    
    Returns:
        QuantumCircuit: circuito que prepara |Φ+⟩
    """
    # TODO: Implementar
    # H no qubit 0, CNOT(0,1)
    pass

# TODO: Criar e visualizar

# %% [markdown]
# ## 2. Estado |Φ-⟩
#
# |Φ-⟩ = (|00⟩ - |11⟩) / √2

# %%
def create_bell_phi_minus() -> QuantumCircuit:
    """
    Cria o estado |Φ-⟩.
    
    Returns:
        QuantumCircuit: circuito que prepara |Φ-⟩
    """
    # TODO: Implementar
    # Dica: |Φ+⟩ com uma porta Z adicional
    pass

# TODO: Criar e visualizar

# %% [markdown]
# ## 3. Estado |Ψ+⟩
#
# |Ψ+⟩ = (|01⟩ + |10⟩) / √2

# %%
def create_bell_psi_plus() -> QuantumCircuit:
    """
    Cria o estado |Ψ+⟩.
    
    Returns:
        QuantumCircuit: circuito que prepara |Ψ+⟩
    """
    # TODO: Implementar
    # Dica: |Φ+⟩ com uma porta X adicional
    pass

# TODO: Criar e visualizar

# %% [markdown]
# ## 4. Estado |Ψ-⟩
#
# |Ψ-⟩ = (|01⟩ - |10⟩) / √2

# %%
def create_bell_psi_minus() -> QuantumCircuit:
    """
    Cria o estado |Ψ-⟩.
    
    Returns:
        QuantumCircuit: circuito que prepara |Ψ-⟩
    """
    # TODO: Implementar
    # Dica: Combine X e Z com |Φ+⟩
    pass

# TODO: Criar e visualizar

# %% [markdown]
# ## 5. Medir os Estados de Bell
#
# Execute múltiplas vezes e observe as correlações.

# %%
def measure_bell_state(circuit: QuantumCircuit, shots: int = 1024) -> dict:
    """
    Mede um estado de Bell.
    
    Returns:
        dict: contagens de cada resultado
    """
    # TODO: Adicionar medições e executar
    pass

# TODO: Medir cada estado de Bell e plotar histogramas

# %% [markdown]
# ## 6. Verificar Emaranhamento
#
# Observe que:
# - Nunca obtemos |01⟩ ou |10⟩ para |Φ±⟩
# - Nunca obtemos |00⟩ ou |11⟩ para |Ψ±⟩
#
# Isso é a **correlação perfeita** do emaranhamento!

# %%
# TODO: Executar 1000 shots de cada estado e verificar as correlações

# %% [markdown]
# ## 7. Conclusão
#
# Responda:
# - O que torna os estados de Bell "especiais"?
# - Por que são chamados de "maximamente emaranhados"?
# - Se você medir um qubit e obtiver |0⟩, o que você sabe sobre o outro no estado |Φ+⟩?

# %% [markdown]
# **Resposta:**
#
# _TODO: Escrever sua análise aqui_
